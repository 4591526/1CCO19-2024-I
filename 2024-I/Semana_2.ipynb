# %% [markdown]
# #**Variables y tipos de datos en Python**
# Luisa Gomez (luisa.gomez@pucp.edu.pe)
# * [Github](https://github.com/4591526)
#
# ###**Objetivos**
# *   Repaso de la función `print()`
# *   Asignar variables
# *   Trabajar con varios tipos de datos en Python
# *   Convertir los datos de un tipo a otro

# %% [markdown]
# ###**Contenidos**
#
# * Repaso: Función `print()`
# * Variables
#  *   Nombres de las variables
#
# * Tipos de datos en Python
#  * Integers
#  * Floats
#  * Conversión de un tipo de dato a otro tipo de dato
#  * Ejercicio: Tipos de datos

# %% [markdown]
# ----------
# # **Repaso: Función `print()`**
# La función `print()` muestra el valor de una cadena (string) dentro de los paréntesis en la pantalla (output).
# La función `print()` admite varios argumentos seguidos y separados por comas.
#
# Los siguientes argumentos se muestran en el mismo orden y en la misma línea, separados por un espacio:

# %%
print("Hola", "Adiós")
# Out:
# Hola Adiós

# %% [markdown]
# Cuando se trata de dos cadenas seguidas, se puede no escribir comas entre ellas. Sin embargo, las cadenas se escribirán sin un espacio en blanco entre ellas:

# %%
print("Hola" "Adiós")
# Out:
# HolaAdiós

# %% [markdown]
# Como las comillas indican el principio y el final de una cadena, si se escriben comillas dentro de comillas se produce un error de sintaxis.

# %%
print("Una persona le dice a otro: "Hola"")
# Out:
#   File "<ipython-input-9-2f776d4e84dc>", line 1
#     print("Una persona le dice a otro: "Hola"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Corregimos el código anterior
print("Una persona le dice a otro: 'Hola'")
# Out:
# Una persona le dice a otro: 'Hola'

# %%
### Escribir la fecha de hoy como string usando la función print()
print("26/03/2024")
# Out:
# 26/03/2024

# %% [markdown]
# ________
# ##**Variables**
#
# En vez de escribir el valor directamente en la función `print()`, podemos asignar el valor a una variable y luego usar la variable dentro de la función `print()`
#
# Cuando pasamos un valor a la función `print()`, obtenemos el mismo resultado que si pasamos una variable que contiene ese valor.

# %%
gato = "Miau"
print(gato)
# Out:
# Miau

# %% [markdown]
# "Miau" es un pedazo de texto que llamamos una cadena de caracteres o *string* en inglés. Los **strings** en Python siempre van entre comillas simples o dobles. Recuerden que sin esas comillas, Python pensará que *Miau* es una variable porque los nombres de las variables no van entre comillas.
#
# Los lenguajes de programación pueden verse como **maneras 'formales' de decirle a tu computadora que tiene que hacer**. Por lo tanto, los lenguajes de programación hacen uso de reglas estrictas y bien definidas (conocidas como sintaxis).
#
# Más adelante veremos que Python conoce diferentes tipos de valores que podemos usar (texto, números, etc.). Cada tipo de dato tiene su propia sintaxis por tanto Python debe saber cómo diferenciarlos.
#
# Quizás esto suene un poco confuso, pero la primera distinción a tomar en cuenta, que además es muy importante:
#
# * Los nombres de las variables no van entre comillas
# * Los valores que asignamos a las variables van entre comillas si son cadenas de texto
#
# Se ven muy similares, pero son muy diferentes, y tienen propósitos completamente diferentes.
#
# Veamos el siguiente ejemplo:

# %%
curso = "Pensamiento Computacional"
print("curso") # Este es una cadena de texto con el valor "curso"
print(curso) # Este es una variable con el valor "Pensamiento Computacional"
# Out:
# curso
# Pensamiento Computacional

# %% [markdown]
# Como observamos imprimir una cadena de texto "curso" no es lo mismo que imprimir el valor de la variable curso. En el primer caso, estamos imprimiendo el texto "curso", mientras que en el segundo caso estamos imprimiendo el valor de la variable curso, que es "Pensamiento Computacional".

# %% [markdown]
# Por otro lado, la función `print()` permite incluir distintos tipos de datos y variables como argumentos:

# %%
print("Hoy es martes", 26, "de marzo del", 2024)
# Out:
# Hoy es martes 26 de marzo del 2024

# %%
numero_gatos = 4


print("Tengo", numero_gatos, "gatos.")
# Out:
# Tengo 4 gatos.

# %%
#### Creamos una variable que contenga el número de mascotas que tengamos cada uno
### Ejecutamos un print() para indicar "Tengo, nombre_variable, gato/perro."

numero_perro = 2

print("Tengo", numero_perro, "perros llamados Morcilla y Manjar.")
# Out:
# Tengo 2 perros llamados Morcilla y Manjar.

# %% [markdown]
# Si recordamos un poco de matemáticas, este símbolo se te hará un poco familiar `=`. En matemáticas, el símbolo `=` se utiliza para indicar que dos expresiones tienen el mismo valor.
#
# En programación no es tan diferente, pero lo llamamos **asingación**, donde usamos este mismo símbolo `=`, con el nombre de la variable a su izquierda y el valor que queremos asignar a la derecha.
#
# De esta manera estamos asignando un valor y nombrandolo usando el símbolo de asignación `=`, por tanto luego podemos usar fácilmente el nombre de la variable en lugar de tener que escribir el valor completo cada vez que lo necesitemos.
#
# Pensemos en las variables como cajas donde podemos guardar objetos. Cada caja tiene un nombre (variable) y un contenido (valor). En este caso nuestra variable `x` es una especie de etiqueta que le pusimos a la caja para identificarla. En esta caja ponemos lo que nosotros quisieramos, como algún número, en este caso el valor 12. Por tanto en Python, el término **variable** se refiere a la etiqueta que le ponemos a la caja, mientras que el término **valor** se refiere al contenido de la caja.
#
# <figure>
# <center>
# <img width=600 src='https://drive.google.com/uc?id=1FFB8tZVVXxX2koxAzq9sgm96qTwd21Xz' />
# </figure>
#
#
#
# Hay que tomar en cuenta que nosotros podemos cambiar el contenido de la caja, por tanto podríamos reutilizar los nombres de variables para guardar diferentes valores. Por ejemplo:

# %%
mensaje = "Me gustan los perros"
print(mensaje)
mensaje = "Me gustan los gatos"
print(mensaje)
# Out:
# Me gustan los perros
# Me gustan los gatos

# %%
### Finalmente, ¿cuál es el valor de la variable mensaje?
mensaje
# Out:
# 'Me gustan los gatos'

# %% [markdown]
# ###**Nombres de las variables**
# Hay que tener en cuenta que los **nombres de variables** `mensaje` y `x` utilizados arriba no son parte de Python. En principio, podrías usar cualquier nombre que te guste. Incluso si cambias la variable `mensaje` por algo como `gato` o `goku`, el ejemplo seguiría funcionando:

# %%
###¿Qué sucede aquí?
goku_2 = 12
print(goku_2 + 3)
# Out:
# 15

# %% [markdown]
# Sin embargo, los nombres de las variables solo son **válidos** si cumplen con ciertas reglas. De lo contrario, obtendrás un error de Python. Aquí hay algunas reglas para nombrar variables en Python:
#
# - Los nombres de las variables deben comenzar con una letra (a - z, A - B) o un guión bajo (_).
# - El resto del nombre de la variable puede consistir en letras, números y guiones bajos.
#
# Asimismo, si bien puedes usar cualquier nombre mientras sean válidos, hay ciertos **convenciones de nombramiento** que es mejor seguir ([PEP8 Style Guide for Python Code](https://www.python.org/dev/peps/pep-0008/)). Por el momento, es suficiente que recuerdes seguir lo siguiente:
#
# - utiliza nombres de variables claros, significativos y descriptivos para que tu código siga siendo comprensible
# - emplea el estilo `minusculas_con_guiones_bajos`, con caracteres en minúscula y guiones bajos para separar palabras
# - no utilices nombres reservados, como `print` o `sum` (estos se volverán de otro color en los Notebooks). [Aquí](https://www.w3schools.com/python/python_ref_keywords.asp) hay una lista de palabras reservadas en Python.
#
# Por ejemplo, el siguiente nombre de variable es válido, mucho más descriptivo que `x` y sigue las convenciones de nomenclatura:

# %%
segundos_semana = 60 * 60 * 24 * 7
print(segundos_semana)
# Out:
# 604800

# %% [markdown]
# ### Ejercicio 1
#
# Escribe un programa en Python que calcule el número de días en tres décadas. Hazlo en una sola línea de código y asigna el resultado a una variable con un nombre claro. Imprime el resultado.

# %% [markdown]
# ### Ejercicio 2
#
# Reescribe el código anterior asignando cada uno de los valores numéricos a una variable con un nombre claro. Luego, utiliza estas variables para calcular el número de días en tres décadas.

# %% [markdown]
# ---
# #**Tipos de datos en Python**
# Python es un lenguaje orientado a objetos(datos).
# Los tipos de datos más comunes son strings, integers y floats.
# Cada vez que escribimos un texto en Python, estamos utilizando **strings** (cadena de caracteres).
# Los números más comunes, por otro lado, son **integers**  (por ejemplo, -1, 0, 100) y **floats**,que representan números reales (por ejemplo, 3.14, -42.0).
#
#
#
# ![clase 1.jpg](data:image/jpeg;base64,...)

# %%
# Integer (entero)

6
# Out:
# 6

# %%
# Float (decimal)

2.14
# Out:
# 2.14

# %%
#  String (cadena de caracteres)

"Hola, Python"
# Out:
# 'Hola, Python'

# %% [markdown]
# Asimismo, puedes hacer que Python te diga el tipo de dato usando la función incorporada `type()`.
# Notarás que Python se refiere a los números enteros como **int**, decimales como **float**, y los strings como **str**.

# %%
# Tipo de dato: 21

type(21)
# Out:
# int

# %%
# Tipo de dato: 3.14

type(3.14)
# Out:
# float

# %%
# Tipo de dato: 12.0

type(12.0)
# Out:
# float

# %%
# Tipo de dato: "Hello, Python 101!"

type("Hello, Python 101!")
# Out:
# str

# %% [markdown]
# ###**Integers**
# Los números enteros pueden ser números negativos o positivos.

# %%
# Suma de dos integers

print(3 + 5)
# Out:
# 8

# %%
# Resta de dos integers

print(2 - 10)
# Out:
# -8

# %%
# Comprueba el tipo de dato de la multiplicación de los resultados anteriores

# %% [markdown]
# ###**Floats**
# Floats representan números reales; son un superconjunto de números enteros pero también incluyen "números decimales".

# %% [markdown]
# **Convertir integers en floats:**
# Cuando convertimos un integer en un float, en realidad no cambiamos el valor del número.

# %%
# Convirtamos 2 en un float

float(2)
# Out:
# 2.0

# %% [markdown]
# **Convertir floats en integers:**
#  Si convertimos un float en un integer, potencialmente podríamos perder algo de información.

# %%
# Convirtamos 1.1 en integer, resultará en la pérdida de información.

int(1.1)
# Out:
# 1

# %% [markdown]
# **Convertir de strings a integers o floats:**
# A veces, podemos tener un string que contiene un número dentro de ella. Si este es el caso, podemos convertir ese string que representa un número en un entero usando int():

# %%
# Convirtamos un string en un integer

int('1')
# Out:
# 1

# %% [markdown]
# Pero si intentas hacerlo con un string que no es una coincidencia perfecta para un número, obtendrás un error.

# %%
# Convirtamos un string en un integer con error

int('1 or 2 people')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-985c8158d612> in <cell line: 3>()
#       1 # Convirtamos un string en un integer con error
#       2
# ----> 3 int('1 or 2 people')
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %% [markdown]
# Ten en cuenta que las cadenas se pueden representar con comillas simples ('1.2') o doble comillas ("1.2"), pero **nunca combinados** ("1.2').

# %% [markdown]
# ###**Ejercicio: Tipos de datos**
# ¿Cuál es el tipo de datos del resultado de: 6 / 4?

# %%
type(6/4)
# Out:
# float

# %% [markdown]
# ¿Cuál es el tipo de datos del resultado de: 6 // 4?

# %%
type(6//4)
# Out:
# int

# %% [markdown]
# ¿Cuál es la diferencia entre el uso de  / y //?
