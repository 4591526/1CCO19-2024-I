# %% [markdown]
# #**Tu primer código de Python**
# Luisa Gomez (luisa.gomez@pucp.edu.pe)
#
# ###**Objetivos**
# *   Escribir un código básico en Python
#
# ###**Contenidos**
# * "Hola mundo" en Python
#  * ¿Qué está ocurriendo aquí?
#  * Escribir comentarios en Python
#  * Errores en Python
#  * ¿Python sabe acerca de tu error antes de ejecutar tu código?
#  * Ejercicio: Tu primer código

# %% [markdown]
# ---
# ### **¿Qué es Python?**
# Python es un lenguaje de programación de alto nivel. Podemos considerar a este lenguaje como el puente entre el lenguaje humano y el lenguaje de las máquinas. Su aproximación al lenguaje humano lo hace más fácil de aprender en comparación con otros lenguajes de programación.
#
# Practicaremos Python utilizando Notebooks a través de Google Colab. Colab es un entorno de programación gratuito que se ejecuta desde el navegador. No se necesitará instalar nada previamente para usarlo.
#
# ### **Notebooks de Python**
# Estos Notebooks contienen instrucciones y lo que se denomina 'bloques de texto'. Las instrucciones son párrafos de texto que explican los conceptos que vamos a utilizar. Los 'bloques de código' contienen el código Python.
# Los Notebooks son bastante sencillos. Algunos consejos para empezar:
#
# * Las celdas de un notebook contienen código o texto. Si ejecutas una celda, se ejecutará el código o se renderizará el texto.
# * Formas de ejecutar una celda:
#     1. Haz clic en el botón de `Run` **(triángulo en un círculo)** en la parte izquierda del bloque de código.
#     2. `Alt` + `Enter` ejecuta la celda actual y crea una nueva celda.
#     3. `Ctrl` + `Enter` ejecuta la celda actual sin crear una nueva celda.
#
# **Consejo**: Manten ordenado tu Notebook. Si ejecutas las celdas de manera desordenada puede que obtengas resultados que no esperas.

# %% [markdown]
# -----
# ###**"Hola mundo" en Python**
# Al aprender a programar, se acostumbra comenzar con un ejemplo sencillo: "Hola mundo". Esta línea de código asegurará que sepamos cómo imprimir una cadena en el output (salida) y cómo ejecutar el código dentro de las celdas en un notebook.

# %%
# Probemos el primer output en Python

print('Hola mundo')
# Out:
# Hola mundo

# %% [markdown]
# ###**¿Qué está ocurriendo aquí?**
# Estamos usando la función `print()` para imprimir el texto *'Hola mundo'* en la pantalla (output).
# Es decir, la función `print()` muestra la cadena de caracteres (argumento)dentro de sus paréntesis en la pantalla.
#
# > **Nota:** Una función es un bloque de código que realiza una tarea específica.
# Las funciones toman entradas (llamadas argumentos, un término para referise a los valores que pones dentro de una función) y devuelven salidas. En este caso, la función `print()` toma el texto 'Hola mundo' como entrada y devuelve el mismo texto como salida, que se muestra en la pantalla.
#
# **¿Cómo podemos modificar el código para que muestre tu nombre en lugar de 'Hello world'?**

# %%
# Imprimamos nuestro nombre

print("Avi")
# Out:
# Avi

# %% [markdown]
# ###**Escribir comentarios en Python**
# ¿Viste que usamos el símbolo `#` para añadir un comentario al código? Los comentarios son líneas de texto que no se ejecutan como código, sino que se utilizan para hacer que el código sea más fácil de entender. Puedes añadir comentarios a tu código para recordar lo que hace, o para ayudar a otros a entenderlo.
#
# Para escribir comentarios en Python, use el símbolo numeral `#` antes de escribir tu comentario. Cuando ejecutes tu código, Python ignorará todo lo que esté más allá del `#`.

# %%
# Escribamos un comentario

print('Hello, Python!') # Esta línea imprime un string
# print('Hi')

# %% [markdown]
# ###**Errores en Python**
# Todos cometemos errores. Para muchos tipos de errores, Python les dirá que han cometido un error al darle un mensaje de error. Es importante leer los mensajes de error detenidamente para comprender realmente dónde se cometió un error y cómo puedes corregirlo.
#
# Por ejemplo, si deletrea **print** como **frint**, Python mostrará un mensaje de error.

# %%
# Corremos una cadena (string) como mensaje de error

frint("Hello, Python!")

# %% [markdown]
# **El mensaje de error te dice:**
# Dónde ocurrió el error, y qué tipo de error fue **(NameError)**. Aquí, Python intentó ejecutar la función **frint**, pero no pudo determinar qué es **frint** ya que no es una función integrada y tampoco la hemos definido previamente.
#
# Notará que si cometemos un tipo diferente de error, al olvidar cerrar el string, obtendremos un error diferente **(i.e., a SyntaxError)**.

# %%
# PR

print("Hello, Python!)

# %% [markdown]
# ###**¿Python sabe acerca de tu error antes de ejecutar tu código?**
# Python es lo que se llama un lenguaje interpretado. Por su parte, los lenguajes compilados (C++, Java, entre otros) examinan todo el programa en el momento de la compilación y pueden advertirle sobre toda clase de errores antes de la ejecución. Por el contrario, Python interpreta línea por línea a medida que lo ejecuta. Python dejará de ejecutar todo el programa cuando encuentre un error.

# %%
# Corre los siguientes strings para ver el orden de ejecución

print("This will be printed")
frint("This will cause an error")
print("This will NOT be printed")

# %% [markdown]
# ###**Ejercicios:**
# En la siguiente celda de código, use la función `print()` para imprimir la frase: **"Pienso, luego existo"**.

# %%
print("Pienso, luego existo")
# Out:
# Pienso, luego existo

# %% [markdown]
# Ahora, mejoremos el código con un comentario. En la celda de código a continuación, impriman la frase anterior u otra de su preferencia y coméntenlo en la misma línea de código.

# %%
### En esta celda de cógido se imprime una frase
print("Pienso, luego existo")

# %%
### Creamos una variable X que contenga el valor 4

x = 4

# %%
print(x)
# Out:
# 4

# %%
### creamos una variable palabra que contega el valor "pelota"

palabra = "pelota"

print(palabra)
# Out:
# pelota

# %%
## Creamos dos variables que contengan un dígito cada uno

m = 9
n = 7

# %%
### cambiamos de valor a la variable m

m = 5

# %%
## Sumamos ambas variables y ejecutamos la función print
print(m + n)
# Out:
# 12

# %%
### Creamos dos variable: una contiene una cadena y la otra un número

palabra = "martes"

fecha = 19

print(palabra + fecha)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4d10f7c11491> in <cell line: 7>()
#       5 fecha = 19
#       6
# ----> 7 print(palabra + fecha)
#
# TypeError: can only concatenate str (not "int") to str
