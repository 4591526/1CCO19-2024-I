# %% [markdown]
# # **Listas y condicionales (if-elif-else) en Python**
# Luisa Gomez (luisa.gomez@pucp.edu.pe)
#
# ## **Objetivos**
# * Repaso de listas
# * Trabajar con condicionales
# * Comprender la sintaxis de las condicionales
#
# ## **Contenidos**
# 1. Listas (II)
#
#   1.1. ¿Cómo crear una lista?
#
#   1.2. ¿Cómo agregar elementos a una lista?
# 2. Condicionales en Python
#
#   2.1. Instrucciones if
#
#   2.2. Decisiones de dos escenarios: if-else
#
#   2.3. Decisiones con múltiples opciones: if-elif-else
#
# 3. Sintaxis de las condicionales
#
#   3.1. Indentación
#
#   3.2. Anidamiento
#
# -----

# %% [markdown]
# ## **1. Listas (II)**
#
# ### **1.1. ¿Cómo crear una lista?**
#
# Crear una lista es bastante sencillo. Observemos los siguientes ejemplos:

# %%
amigos = ['Ana', 'Andrea', 'Erika', "Rodrigo", "Saúl", "Sharon", "Angie"]
actitudes = ['curiosidad','creatividad','determinación']

print(amigos)
print(actitudes)
# Out:
# ['Ana', 'Andrea', 'Erika', 'Rodrigo', 'Saúl', 'Sharon', 'Angie']
# ['curiosidad', 'creatividad', 'determinación']

# %%
numeros_enteros = [12, 14, 20, 18]
diversidad = [True, 3.14, 87, "demasiado"]

print(numeros_enteros)
print(diversidad)
# Out:
# [12, 14, 20, 18]
# [True, 3.14, 87, 'demasiado']

# %% [markdown]
# Las llaves rodean a las listas, y las comas separan los elementos en la lista. Un elemento de una lista puede ser cualquier objeto de Python, incluso otra lista como se explico en la clase anterior.
#
# También puedes crear una lista a partir de un string.

# %% [markdown]
# ## **.split()**
# Esta función divide una cadena en una lista donde cada palabra es un elemento de la lista.

# %%
novela = 'El diario de Ana Frank'

palabras_novela = novela.split()

print(palabras_novela)
# Out:
# ['El', 'diario', 'de', 'Ana', 'Frank']

# %%
oracion = "Fragmento de un texto en prosa constituido por un conjunto de líneas seguidas y caracterizado por el punto y aparte al final de la última."

palabra_oracion = oracion.split()

print(palabra_oracion)
# Out:
# ['Fragmento', 'de', 'un', 'texto', 'en', 'prosa', 'constituido', 'por', 'un', 'conjunto', 'de', 'líneas', 'seguidas', 'y', 'caracterizado', 'por', 'el', 'punto', 'y', 'aparte', 'al', 'final', 'de', 'la', 'última.']

# %%
print(len(palabras_novela)) # número de elementos de cada lista

print(len(palabra_oracion))
# Out:
# 5
# 25

# %%
print(palabras_novela.count("de")) # el número de veces que aparece el término indicado

print(palabra_oracion.count("de"))
# Out:
# 1
# 3

# %% [markdown]
# Asimismo, una lista puede estar vacía. Ten en cuenta que existen dos formas de crear una lista vacía.

# %%
manera_1 = []
print(manera_1)
# Out:
# []

# %% [markdown]
#  ## **list()**
# Esta función se utiliza para crear una lista.

# %%
manera_2 = list()
print(manera_2)
# Out:
# []

# %% [markdown]
# ## **1.2. ¿Cómo agregar elementos a una lista?**
#
# La forma más común de agregar un elemento a una lista es utilizando el método `append()`. La función `append()` se usa en listas para agregar un elemento al final de la lista.
# En contraste, otros métodos como replace (que usamos con strings),
# `replace()` no modifica la cadena original porque las cadenas son inmutables en Python. Devuelve una nueva cadena con el reemplazo.
# Puedes reemplazar todas las apariciones de una subcadena a la vez.
#
# En síntesis,`append()` es exclusivo para listas y modifica la lista añadiendo un elemento al final, y
# `replace()` es exclusivo para cadenas y devuelve una nueva cadena con los cambios, sin alterar la original.

# %%
lista_numeros = [1, 3, 4]
lista_numeros.append(5)
print(lista_numeros)
# Out:
# [1, 3, 4, 5]

# %% [markdown]
# Recuerda que en Python, todas las funciones devuelven un valor. Si no devuelve un valor explícito, entonces devuelve **None** que es como decir "no hay nada que mostrar".

# %%
lista_nueva = lista_numeros.append(0)
print(lista_nueva)
# Out:
# None

# %% [markdown]
# `append()` modifica la lista original

# %%
print(lista_numeros)
# Out:
# [1, 3, 4, 5, 0]

# %% [markdown]
# En comparación, cuando deseamos cambiar un objeto inmutable como una cadena de texto, el método devuelve una copia de la entrada:

# %%
saludo = 'hello'
saludo.replace('l', 'b')  ### al ser un string un dato inmutable requiere de la asignación a una variable para visualizar los cambios
print(saludo)
# Out:
# hello

# %%
print(saludo)
saludo_nuevo = saludo.replace('l', 'b') ### primero va el elemento que se desea cambia, luego va el elemento por el cual se cambiará
print(saludo_nuevo)
print(saludo)
# Out:
# hello
# hebbo
# hello

# %% [markdown]
# # **2. Condicionales en Python**
# Recordemos que un código, no deja de ser un conjunto de instrucciones que son ejecutadas unas tras otra. Gracias a las estructuras de control, podemos cambiar el flujo de ejecución de un programa, haciendo que ciertos bloques de código se ejecuten si y solo si se dan unas condiciones particulares.
#
# ## **2.1. Instrucciones if**
# Puede que te preguntes por qué dedicamos bastante tiempo explicando las expresiones booleanas. Una de las razones es que son el elemento principal en una de las herramientas más utilizadas en Python: las **instrucciones if**. La siguiente imagen explica qué sucede en una **instrucción if** en Python.

# %% [markdown]
# ![if.png](data:image/png;base64,...)

# %%
cantidad = 4 # Prueba cambiando el valor de cantidad
if cantidad <= 5:
    print(cantidad) ### Solo se imprime si la condición de la instrucción if es True
# Out:
# 4

# %%
numero_cualquiera = 4
if numero_cualquiera == 5:
    print("El número es igual a 5.")
if numero_cualquiera > 4:
    print("El número es mayor que 4.")
if numero_cualquiera >= 5:
    print("El número es mayor o igual a 5.")
if numero_cualquiera != 6 :
    print("El número no es igual a 6.")
# Out:
# El número no es igual a 6.

# %% [markdown]
# ## **2.2. Decisiones de dos escenarios: if-else**
#
# Pero, ¿qué pasa si queremos tener opciones para dos escenarios diferentes? Podríamos simplemente usar un montón de instrucciones if. Sin embargo, Python tiene una forma más eficiente. Además del if, también tenemos la **instrucción else** para decisiones de dos vías:

# %% [markdown]
# ![if-else.png](data:image/png;base64,...)

# %%
cantidad = 6 # Prueba cambiando el valor de cantidad
if cantidad <= 5:
    print(cantidad)
else:
    print('El número es mayor a 5.')
# Out:
# El número es mayor a 5.

# %%
palabras_articulo = 550  # Número de palabras del artículo

if palabras_articulo >= 500:
    print("El artículo está listo para ser enviado.")
else:
    print("El artículo es muy corto, por favor amplía el contenido.")
# Out:
# El artículo está listo para ser enviado.

# %% [markdown]
# ## **2.3. Decisiones con múltiples opciones: if-elif-else**
# Si tienes múltiples opciones, puedes usar la **instrucción elif**. Para cada bloque if, puedes tener múltiples instrucciones elif y una instrucción else. Ahora conozcamos la estructura completa del constructo if-elif-else:

# %% [markdown]
# ![if-elif-else.png](data:image/png;base64,...)

# %%
### Condición if

numero = 1

# verificar que el número es mayor a 0
if numero > 0:
    print('El número es positivo.')

print('Este mensaje siempre se ejecutará.')
# Out:
# El número es positivo.
# Este mensaje siempre se ejecutará.

# %%
numero = 1

# verificar que el número es mayor a 0
if numero > 0:
print('El número es positivo.')
# Out:
#   File "<ipython-input-35-cd91cd693ea8>", line 5
#     print('El número es positivo.')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
numero = 1

# verificar que el número es mayor a 0
if numero > 0:
  print('El número es positivo.')
# Out:
# El número es positivo.

# %%
### Condición if-else

numero = -5

if numero > 0:
    print('El número es positivo.')

else:
    print('El número es negativo.')

print('Este mensaje siempre se ejecutará.')
# Out:
# El número es negativo.
# Este mensaje siempre se ejecutará.

# %%
### Condición if-elif-else

numero_entero = -3

if numero_entero > 0:
    print('El número es positivo.')

elif numero_entero < 0:
    print('El número es negativo.')

else:
    print('Cero')

print('Este mensaje siempre se ejecutará.')
# Out:
# El número es negativo.
# Este mensaje siempre se ejecutará.

# %% [markdown]
# **Recuerda:**
#
# **if-if:** tu código revisará todas las declaraciones if
#
# **if-elif:** si una condición resulta en True, no verificará las otras condiciones

# %% [markdown]
# # **3. Sintaxis de las condicinales**
# ## **3.1. Indentación**
# Echemos otro vistazo al ejemplo de arriba (hemos agregado números de línea):
#
# ```
# 1. if cantidad <= 5:
# 2.     print(cantidad)
# 3. else:
# 4.     print('El número es mayor a 5')
# ```
# Es posible que hayas notado que la línea 2 comienza con 4 espacios. La indentación le indica a Python cuándo necesita ejecutar ese fragmento de código. Cuando la expresión booleana en la línea 1 es **True**, Python ejecuta el código desde la siguiente línea que comienza con cuatro espacios o con un tabulador (una sangría) a la derecha. Esto se llama indentación. **Todas las declaraciones con la misma distancia hacia la derecha pertenecen al mismo 'bloque' de código.**
#
# A diferencia de otros lenguajes, Python no utiliza llaves {} para marcar el inicio y el final de fragmentos de código, como las declaraciones if. **El único delimitador es dos puntos : y la indentación del código.** Recuerda que tanto cuatro espacios como tabuladores pueden utilizarse para la indentación. Esta indentación debe usarse de manera consistente en todo tu código. Por ahora, no tienes que preocuparte por esto, ya que un tabulador se convierte automáticamente en cuatro espacios en los notebooks.
#
# Observa el código a continuación. Vemos que el bloque con sangría no se ejecuta, pero sí se ejecutan las líneas de código sin sangría. ¡Ahora cambia el valor de la variable persona! ¡La conversación debería ser un poco más larga ahora!

# %%
persona = "Jisoo"
print("¡Hola!")

if persona == "Jisoo":
    print("¡Hola, Jisoo! ¿Cómo estuvo tu último concierto?")
elif persona == "RM":
    print("¡Hola, RM! ¿Estás escribiendo nuevas letras para tu próximo álbum?")
elif persona == "IU":
    print("¡Hola, IU! ¿Cómo te sientes después de tu nuevo drama?")
else:
    print("¡Hablemos en otro momento, espero verte pronto!")

print("¡Adiós!")
# Out:
# ¡Hola!
# ¡Hola, Jisoo! ¿Cómo estuvo tu último concierto?
# ¡Adiós!

# %%
goles_real_madrid = 2  # Número de goles del Real Madrid
goles_barcelona = 2    # Número de goles del Barcelona

if goles_real_madrid > goles_barcelona:
    print("¡El Real Madrid ha ganado el partido!")
elif goles_barcelona > goles_real_madrid:
    print("¡El Barcelona ha ganado el partido!")
else:
    print("El partido ha terminado en empate.")
# Out:
# El partido ha terminado en empate.

# %% [markdown]
# ## **3.2. Anidamiento**
# Hemos visto que todas las declaraciones con la misma distancia hacia la derecha pertenecen al mismo bloque de código, es decir, las declaraciones dentro de un bloque se alinean verticalmente. El bloque termina en una línea con menos sangría o al final del archivo. Los bloques también pueden contener otros bloques; de esta manera, obtenemos una estructura de bloques anidados. El bloque que debe estar profundamente anidado simplemente se agrega una sangra más a la derecha:

# %% [markdown]
# ![a.png](data:image/png;base64,...)

# %% [markdown]
# Puede haber una situación en la que quieras verificar otra condición después de que una condición se resuelva como True. En tal situación, puedes usar la estructura if anidada. Como puedes ver si ejecutas el código a continuación, la segunda declaración if solo se ejecuta si la primera declaración if devuelve **True**. Intenta cambiar el valor de x para ver qué hace el código.

# %%
x = int(input("Ingresa un número: "))
if x >= 0:
    if x == 0:
        print("Cero")
    else:
        print("Número positivo")
else:
    print("Número negativo")
# Out:
# Ingresa un número: -14
# Número negativo

# %%
# Primero, solicitamos el nombre al beneficiario con la función input() y lo guardamos en una variable
nombre_beneficiario = input("Ingrese su nombre completo: ")

# Verificamos si el nombre contiene solo letras (para evitar nombres numéricos)
if not nombre_beneficiario.isdigit():
    # Segundo, solicitamos la edad del beneficiario y verificamos si es mayor de 18
    edad_beneficiario = int(input("Ingrese su edad: "))

    if edad_beneficiario >= 18:
        # Tercero, solicitamos el ingreso mensual del beneficiario y verificamos si es menor a 1500
        ingreso_mensual = int(input("Ingrese su ingreso mensual: "))

        if ingreso_mensual < 1500:
            print("Datos correctamente ingresados. Eres elegible para el beneficio.")
        else:
            print("Ingreso mensual no válido para el beneficio. Debe ser menor a 1500.")
    else:
        print("No eres elegible para el beneficio, debes tener 18 años o más.")
else:
    print("Nombre no válido. Debes ingresar un nombre sin números.")
# Out:
# Ingrese su nombre completo: Luisa Gomez
# Ingrese su edad: 14
# No eres elegible para el beneficio, debes tener 18 años o más.

# %% [markdown]
# ### **Ejercicio 1**
# Crear un programa en Python utilizando la función `input()` que solicite al usuario ingresar su nombre de usurio (código PUCP) y contraseña para registrarse en el campus virtual de la PUCP.
#
# Una vez ingresados los datos, el programa debe mostrar un mensaje indicando que el usuario ha sido creado exitosamente, junto con el nombre del usuario y una representación oculta de la contraseña (*). Para la representación oculta puedes usar la función `len()`.
#
# **Recuerda siempre comentar tu código.**

# %% [markdown]
# ------
# ### **Solución propuesta**
#
# Recuerden que siempre hay distintas formas de resolver un ejercicio.

# %%
# Inicialmente podemos escribir un mensaje de bienvenida
print("¡Bienvenido al registro del Campus Virtual de la PUCP")

# Creamos una variable para solicitar al usuario que ingrese su código PUCP
nombre_usuario = input("Por favor, ingresa tu código PUCP: ")

# Creamos otra variable para solicitar la contraseña
contraseña = input("Por favor, ingresa tu contraseña: ")

# Si deseamos validar que los datos anteriores ingresados podemos usar declaraciones if-else
if nombre_usuario.isdigit(): # Si el valor ingresado contiene caracteres numéricos es True, se debe imprimir los siguientes mensajes
  print("Usuario:", nombre_usuario) # Estos argumentos se imprimen siempre y cuando se cumpla la condición if
  print("Contraseña:", len(contraseña) * "*") # El segundo argumento se imprime en una representación secreta donde se reemplaza la contraseña por asteriscos y se repite ese signo según el largo del string asignado a contraseña
else:  # Si el valor ingresado no cumple la condición if, se imprime el siguiente mensaje
  print("Usuario incorrecto.") # Este mensaje se imprime si la condición if es False
# Out:
# ¡Bienvenido al registro del Campus Virtual de la PUCP
# Por favor, ingresa tu código PUCP: 20154826
# Por favor, ingresa tu contraseña: dknvdkn
# Usuario: 20154826
# Contraseña: *******

# %% [markdown]
# ###**Ejercicio 2**
# Una agencia de publicidad está trabajando con un cliente que quiere lanzar una campaña digital para su nuevo producto. Dependiendo del presupuesto que el cliente quiera invertir, se seleccionará una de las siguientes estrategias:
#
# * Si el presupuesto es mayor a 50,000 USD, se recomienda una campaña omnicanal, que incluye redes sociales, Google Ads, y marketing de influencers.
# * Si el presupuesto está entre 20,000 y 50,000 USD, se sugiere una campaña en redes sociales y Google Ads.
# * Si el presupuesto es menor a 20,000 USD, se recomienda una campaña solo en redes sociales.
#
# Escribe un programa en Python que reciba como entrada el presupuesto del cliente y, basándose en este, imprima la estrategia recomendada.

# %% [markdown]
# ----
# ### **Solución**

# %%
# En primer lugar, se crea una variable que guarde la inversión del cliente para una campaña publicitaria
monto_inversión = int(input("Ingrese su presupuesto en USD (dólares): ")) # Convertimos el valor ingresado a entero para evaluar el tipo de campaña publicitaria que se puede ofrecer

# En segundo lugar, evaluamos el tipo de campaña que puede cubrir el presupuesto del usuario con declaraciones if-elif-else
if monto_inversión >= 50000: # Si el presupuesto cumple la condición if se imprimirá el mensaje indentado
   print("Se recomienda una campaña en redes sociales, Google Ads y marketing de influencers.")
elif 20000 < monto_inversión < 50000: # Si el presupuesto de la condición if es False, se evalua si cumple la condición elif
   print("Se sugiere una campaña en redes sociales y Google Ads.")
else: # Si el presupuesto no cumple con las condiciones if-elif, se imprimirá el mensaje indentado a la condición else
   print("Se recomienda una campaña solo en redes sociales.")
# Out:
# Ingrese su presupuesto en USD (dólares): 54005
# Se recomienda una campaña en redes sociales, Google Ads y marketing de influencers.
